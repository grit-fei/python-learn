# %%
print('''line1
line2
line3''')
# Out:
# line1
# line2
# line3

# %%
n = 123
f = 456.789
s1 = 'Hello, world'
s2 = 'Hello, \'Adam\''
s3 = r'Hello, "Bart"'
s4 = r'''Hello,
Bob!'''

print(n)
print(f)
print(s1)
print(s2)
print(s3)
print(s4)
# Out:
# 123
# 456.789
# Hello, world
# Hello, 'Adam'
# Hello, "Bart"
# Hello,
# Bob!

# %%
s1 = 72
s2 = 85
r = (s2-s1)/s1*100
print('hello, %s, your score increased by %.1f %%' % ('小明',r))
# Out:
# hello, 小明, your score increased by 18.1 %
